# %%
import numpy as np
data = np.load('./data/s05_15_21.npy')
data
# Out:
# array([[18.65754643, 21.5737596 , 26.31451932, ..., 29.23835481,
#          4.38788331, 18.29171218],
#        [23.41339159, 15.72324853, 28.1419165 , ..., 33.62410803,
#         10.96970827, 20.48671764],
#        [21.58422038, 10.23839439, 29.23835481, ..., 35.81698464,
#          7.31313885, 18.29171218],
#        ...,
#        [25.60839706, 40.95357755, 29.96931368, ...,  8.04054757,
#         12.61516451, 14.2675355 ],
#        [13.90170126, 39.85660673, 31.06575198, ..., 15.16739656,
#          6.76465344, 12.43836428],
#        [ 2.19500546, 25.23032903, 19.73588949, ...,  6.94410927,
#         12.61516451, 10.79211019]])

# %%
import matplotlib.pyplot as plt
plt.imshow(data, cmap='gray', aspect='auto')
plt.xlabel('Distance')
plt.ylabel('Time or Depth')
plt.title('Sonar Data Visualization')
plt.colorbar()
plt.show()
